# %% [markdown]
# <h1> <u>Drought Prediction</u>: Data Wrangling </h1>

# %% [markdown]
# <h3> Initial Import of Libraries and Loading of Data </h3>

# %% [markdown]
# <b> Import Libraries</b>

# %%
# Import pandas, matplotlib.pyplot, and seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# <b> Downloading the Soil, Meteorological, and Drought Data and loading them into the file. </b>

# %% [markdown]
# Data dictionary and data downloaded from Kaggle on 3/27/2022 at:
# https://www.kaggle.com/datasets/cdminix/us-drought-meteorological-data
#
# Preprocessing notebooks to create the Kaggle dataset:
# https://github.com/MiniXC/droughted_scripts

# %%
# Local location of the data
# local_data = 'D:\\Data_Science\\DroughtProject\\Data\\' # Location on Windows 
local_data = '/Users/tanishalohchab/Downloads/drought_prediction-main/dataset/'

# The data is split into four csv files.
# Load all four files
soil_set = pd.read_csv(local_data + 'soil_data.csv')
test_set = pd.read_csv(local_data + 'test_timeseries.csv')
train_set = pd.read_csv(local_data + 'train_timeseries.csv')
validation_set = pd.read_csv(local_data + 'validation_timeseries.csv')

# %% [markdown]
# ### Information summary of loaded data.
#
# <b> Data type information in the four files. </b>

# %%
soil_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3109 entries, 0 to 3108
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fips           3109 non-null   int64
#  1   lat            3109 non-null   float64
#  2   lon            3109 non-null   float64
#  3   elevation      3109 non-null   int64
#  4   slope1         3109 non-null   float64
#  5   slope2         3109 non-null   float64
#  6   slope3         3109 non-null   float64
#  7   slope4         3109 non-null   float64
#  8   slope5         3109 non-null   float64
#  9   slope6         3109 non-null   float64
#  10  slope7         3109 non-null   float64
#  11  slope8         3109 non-null   float64
#  12  aspectN        3109 non-null   float64
#  13  aspectE        3109 non-null   float64
#  14  aspectS        3109 non-null   float64
#  15  aspectW        3109 non-null   float64
#  16  aspectUnknown  3109 non-null   float64
#  17  WAT_LAND       3109 non-null   float64
#  18  NVG_LAND       3109 non-null   float64
#  19  URB_LAND       3109 non-null   float64
#  20  GRS_LAND       3109 non-null   float64
#  21  FOR_LAND       3109 non-null   float64
#  22  CULTRF_LAND    3109 non-null   float64
#  23  CULTIR_LAND    3109 non-null   float64
#  24  CULT_LAND      3109 non-null   float64
#  25  SQ1            3109 non-null   int64
#  26  SQ2            3109 non-null   int64
#  27  SQ3            3109 non-null   int64
#  28  SQ4            3109 non-null   int64
#  29  SQ5            3109 non-null   int64
#  30  SQ6            3109 non-null   int64
#  31  SQ7            3109 non-null   int64
# dtypes: float64(23), int64(9)
# memory usage: 777.4 KB

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2271948 entries, 0 to 2271947
# Data columns (total 21 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   fips         int64
#  1   date         object
#  2   PRECTOT      float64
#  3   PS           float64
#  4   QV2M         float64
#  5   T2M          float64
#  6   T2MDEW       float64
#  7   T2MWET       float64
#  8   T2M_MAX      float64
#  9   T2M_MIN      float64
#  10  T2M_RANGE    float64
#  11  TS           float64
#  12  WS10M        float64
#  13  WS10M_MAX    float64
#  14  WS10M_MIN    float64
#  15  WS10M_RANGE  float64
#  16  WS50M        float64
#  17  WS50M_MAX    float64
#  18  WS50M_MIN    float64
#  19  WS50M_RANGE  float64
#  20  score        float64
# dtypes: float64(19), int64(1), object(1)
# memory usage: 364.0+ MB

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19300680 entries, 0 to 19300679
# Data columns (total 21 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   fips         int64
#  1   date         object
#  2   PRECTOT      float64
#  3   PS           float64
#  4   QV2M         float64
#  5   T2M          float64
#  6   T2MDEW       float64
#  7   T2MWET       float64
#  8   T2M_MAX      float64
#  9   T2M_MIN      float64
#  10  T2M_RANGE    float64
#  11  TS           float64
#  12  WS10M        float64
#  13  WS10M_MAX    float64
#  14  WS10M_MIN    float64
#  15  WS10M_RANGE  float64
#  16  WS50M        float64
#  17  WS50M_MAX    float64
#  18  WS50M_MIN    float64
#  19  WS50M_RANGE  float64
#  20  score        float64
# dtypes: float64(19), int64(1), object(1)
# memory usage: 3.0+ GB

# %%
validation_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2268840 entries, 0 to 2268839
# Data columns (total 21 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   fips         int64
#  1   date         object
#  2   PRECTOT      float64
#  3   PS           float64
#  4   QV2M         float64
#  5   T2M          float64
#  6   T2MDEW       float64
#  7   T2MWET       float64
#  8   T2M_MAX      float64
#  9   T2M_MIN      float64
#  10  T2M_RANGE    float64
#  11  TS           float64
#  12  WS10M        float64
#  13  WS10M_MAX    float64
#  14  WS10M_MIN    float64
#  15  WS10M_RANGE  float64
#  16  WS50M        float64
#  17  WS50M_MAX    float64
#  18  WS50M_MIN    float64
#  19  WS50M_RANGE  float64
#  20  score        float64
# dtypes: float64(19), int64(1), object(1)
# memory usage: 363.5+ MB

# %%
# Convert date column from object to datetime for training, validation, and test set
train_set['date'] = pd.to_datetime(train_set['date'], errors='coerce')
validation_set['date'] = pd.to_datetime(validation_set['date'], errors='coerce')
test_set['date'] = pd.to_datetime(test_set['date'], errors='coerce')

# %%
# Date range for training, validation, and test set
print(train_set.date.describe(), '\n')
print(validation_set.date.describe(), '\n')
print(test_set.date.describe(), '\n')
# Out:
# count                         19300680
# mean     2008-07-01 11:59:59.999999744
# min                2000-01-01 00:00:00
# 25%                2004-04-01 00:00:00
# 50%                2008-07-01 12:00:00
# 75%                2012-10-01 00:00:00
# max                2016-12-31 00:00:00
# Name: date, dtype: object
#
# count                2268840
# mean     2017-12-31 12:00:00
# min      2017-01-01 00:00:00
# 25%      2017-07-02 00:00:00
# 50%      2017-12-31 12:00:00
# 75%      2018-07-02 00:00:00
# max      2018-12-31 00:00:00
# Name: date, dtype: object
#
# count                          2271948
# mean     2019-12-31 23:59:59.999999232
# min                2019-01-01 00:00:00
# 25%                2019-07-02 00:00:00
# 50%                2020-01-01 00:00:00
# 75%                2020-07-02 00:00:00
# max                2020-12-31 00:00:00
# Name: date, dtype: object

# %%
print('Training Set date range: ', (train_set.date.min(), train_set.date.max()), '\n')
print('Validation Set date range: ', (validation_set.date.min(), validation_set.date.max()), '\n')
print('Test Set date range: ', (test_set.date.min(), test_set.date.max()))
# Out:
# Training Set date range:  (Timestamp('2000-01-01 00:00:00'), Timestamp('2016-12-31 00:00:00'))
#
# Validation Set date range:  (Timestamp('2017-01-01 00:00:00'), Timestamp('2018-12-31 00:00:00'))
#
# Test Set date range:  (Timestamp('2019-01-01 00:00:00'), Timestamp('2020-12-31 00:00:00'))

# %% [markdown]
# #### The actual date range of your dataset does not match what was originally expected or documented in the metadata. However, since the different subsets (training, validation, and test) do not share overlapping dates, there is no risk of data leakage.

# %% [markdown]
# | Data Set | Date Range |
# | -: | :- |
# | Training Set | 2000 - 2016 |
# | Validation Set | 2017 - 2018 |
# | Test  Set | 2019 - 2020 |

# %% [markdown]
# ##### Let's look at the values in the datasets that we have.|

# %%
soil_set.head()
# Out:
#    fips        lat        lon  elevation  slope1  slope2  slope3  slope4  \
# 0  1001  32.536382 -86.644490         63  0.0419  0.2788  0.2984  0.2497
# 1  1005  31.870670 -85.405456        146  0.0158  0.1868  0.5441  0.2424
# 2  1003  30.659218 -87.746067         52  0.0746  0.4370  0.4415  0.0469
# 3  1007  33.015893 -87.127148         93  0.0144  0.1617  0.3714  0.3493
# 4  1009  33.977448 -86.567246        198  0.0050  0.0872  0.2799  0.3576
#
#    slope5  slope6  ...  CULTRF_LAND  CULTIR_LAND  CULT_LAND  SQ1  SQ2  SQ3  \
# 0  0.1142  0.0170  ...    56.293411     1.014811  57.308224    1    1    1
# 1  0.0106  0.0003  ...    72.578804     1.828159  74.406960    3    2    1
# 2  0.0000  0.0000  ...    59.843639     2.996914  62.840553    3    2    1
# 3  0.0898  0.0134  ...     1.916593     0.008330   1.924924    3    2    1
# 4  0.1477  0.1037  ...     1.891909     0.027488   1.919397    3    2    1
#
#    SQ4  SQ5  SQ6  SQ7
# 0    1    1    1    2
# 1    1    1    1    1
# 2    2    1    1    1
# 3    1    1    1    1
# 4    1    1    1    1
#
# [5 rows x 32 columns]

# %%
train_set.head()
# Out:
#    fips       date  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  1001 2000-01-01     0.22  100.51   9.65  14.74   13.51   13.51    20.96
# 1  1001 2000-01-02     0.20  100.55  10.42  16.69   14.71   14.71    22.80
# 2  1001 2000-01-03     3.65  100.15  11.76  18.49   16.52   16.52    22.73
# 3  1001 2000-01-04    15.95  100.29   6.42  11.40    6.09    6.10    18.09
# 4  1001 2000-01-05     0.00  101.15   2.95   3.86   -3.29   -3.20    10.82
#
#    T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 0    11.46  ...  14.65   2.20       2.94       1.49         1.46   4.85
# 1    12.61  ...  16.60   2.52       3.43       1.83         1.60   5.33
# 2    15.32  ...  18.41   4.03       5.33       2.66         2.67   7.53
# 3     2.16  ...  11.31   3.84       5.67       2.08         3.59   6.73
# 4    -2.66  ...   2.65   1.60       2.50       0.52         1.98   2.94
#
#    WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# 0       6.04       3.23         2.81    NaN
# 1       6.13       3.72         2.41    NaN
# 2       9.52       5.87         3.66    NaN
# 3       9.31       3.74         5.58    1.0
# 4       4.85       0.65         4.19    NaN
#
# [5 rows x 21 columns]

# %%
validation_set.head()
# Out:
#    fips       date  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  1001 2017-01-01    32.50  100.02  10.47  14.69   14.47   14.47    17.68
# 1  1001 2017-01-02    63.52  100.04  12.75  17.96   17.75   17.75    20.30
# 2  1001 2017-01-03    18.82   99.69   9.74  14.24   13.44   13.44    18.48
# 3  1001 2017-01-04     0.01  100.02   5.21   8.10    3.86    3.88    11.74
# 4  1001 2017-01-05     0.01   99.89   4.54   5.91    2.20    2.22    13.07
#
#    T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 0    10.53  ...  14.63   2.14       2.71       1.52         1.19   4.40
# 1    16.14  ...  17.85   2.75       4.31       1.60         2.71   5.50
# 2     9.29  ...  14.06   2.25       3.73       1.64         2.09   4.80
# 3     2.12  ...   8.08   2.63       3.95       1.34         2.60   4.98
# 4    -0.18  ...   5.85   1.76       2.76       0.47         2.28   3.43
#
#    WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# 0       5.96       2.25         3.71    NaN
# 1       8.16       4.05         4.11    NaN
# 2       7.27       2.54         4.72    2.0
# 3       6.16       3.36         2.80    NaN
# 4       4.70       0.66         4.04    NaN
#
# [5 rows x 21 columns]

# %%
test_set.head()
# Out:
#    fips       date  PRECTOT      PS  QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  1001 2019-01-01     2.25  100.51  9.69  14.71   13.55   13.52    17.38
# 1  1001 2019-01-02     4.94  100.48  8.65  13.05   11.83   11.74    17.76
# 2  1001 2019-01-03    20.74  100.03  8.59  12.12   11.67   11.67    13.74
# 3  1001 2019-01-04    16.17   99.47  7.93  11.80   10.38    9.59    18.19
# 4  1001 2019-01-05     0.01  100.39  5.32   7.91    4.73    4.71    14.37
#
#    T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 0    10.92  ...  14.63   1.20       1.50       0.79         0.71   2.74
# 1     9.54  ...  13.06   1.02       1.35       0.32         1.03   2.13
# 2    10.44  ...  12.12   1.83       4.23       0.34         3.88   3.41
# 3     5.44  ...  11.72   3.75       5.25       2.34         2.91   6.78
# 4     3.68  ...   7.75   2.32       2.90       1.69         1.21   4.42
#
#    WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# 0       4.01       1.23         2.78    0.0
# 1       3.37       0.56         2.81    NaN
# 2       7.49       0.72         6.77    NaN
# 3       9.61       4.90         4.71    NaN
# 4       5.87       3.15         2.72    NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# <b><u>Field for Drought Score Category</u>: The Drought Score in the None, D0, D1, D2, D3, and D4 categories is the score field.  While the weather factors are assessed everyday, the Drought Score is only assessed once a week.  Due to its weekly evaluation, the NaN score represents daily meteorological scores that do not immediately correlate with the drought score.

# %% [markdown]
#  The dates covered by all three data sets are identical. This contradicts the Kaggle website's metadata, which said that the test set was from 2012 to 2020, the validation set was from 2010 to 2011, and the training set was from 2000 to 2009.   According to an examination of the raw CSV data, the test set seems to begin in 2019, the validation set in 2017, and the training set in 2000.   It looks like there is a problem importing the CSV file into the Pandas dataframe.

# %% [markdown]
# <h3>Characterizing Null Values within the Dataset</h3>

# %%
# SOIL_SET Null Value exploration
missing_soil = pd.concat([soil_set.isnull().sum(), 100 * soil_set.isnull().mean()], axis=1)
missing_soil.columns=['count', '%']
missing_soil.sort_values(by='count', ascending=False)
# Out:
#                count    %
# fips               0  0.0
# lat                0  0.0
# SQ6                0  0.0
# SQ5                0  0.0
# SQ4                0  0.0
# SQ3                0  0.0
# SQ2                0  0.0
# SQ1                0  0.0
# CULT_LAND          0  0.0
# CULTIR_LAND        0  0.0
# CULTRF_LAND        0  0.0
# FOR_LAND           0  0.0
# GRS_LAND           0  0.0
# URB_LAND           0  0.0
# NVG_LAND           0  0.0
# WAT_LAND           0  0.0
# aspectUnknown      0  0.0
# aspectW            0  0.0
# aspectS            0  0.0
# aspectE            0  0.0
# aspectN            0  0.0
# slope8             0  0.0
# slope7             0  0.0
# slope6             0  0.0
# slope5             0  0.0
# slope4             0  0.0
# slope3             0  0.0
# slope2             0  0.0
# slope1             0  0.0
# elevation          0  0.0
# lon                0  0.0
# SQ7                0  0.0

# %%
# TRAIN_SET Null Value exploration
missing_train = pd.concat([train_set.isnull().sum(), 100 * train_set.isnull().mean()], axis=1)
missing_train.columns=['count', '%']
missing_train.sort_values(by='count', ascending=False)
# Out:
#                 count          %
# score        16543884  85.716586
# TS                  0   0.000000
# WS50M_RANGE         0   0.000000
# WS50M_MIN           0   0.000000
# WS50M_MAX           0   0.000000
# WS50M               0   0.000000
# WS10M_RANGE         0   0.000000
# WS10M_MIN           0   0.000000
# WS10M_MAX           0   0.000000
# WS10M               0   0.000000
# fips                0   0.000000
# date                0   0.000000
# T2M_MIN             0   0.000000
# T2M_MAX             0   0.000000
# T2MWET              0   0.000000
# T2MDEW              0   0.000000
# T2M                 0   0.000000
# QV2M                0   0.000000
# PS                  0   0.000000
# PRECTOT             0   0.000000
# T2M_RANGE           0   0.000000

# %%
# VALIDATION_SET Null Value exploration
missing_valid = pd.concat([validation_set.isnull().sum(), 100 * validation_set.isnull().mean()], axis=1)
missing_valid.columns=['count', '%']
missing_train.sort_values(by='count', ascending=False)
# Out:
#                 count          %
# score        16543884  85.716586
# TS                  0   0.000000
# WS50M_RANGE         0   0.000000
# WS50M_MIN           0   0.000000
# WS50M_MAX           0   0.000000
# WS50M               0   0.000000
# WS10M_RANGE         0   0.000000
# WS10M_MIN           0   0.000000
# WS10M_MAX           0   0.000000
# WS10M               0   0.000000
# fips                0   0.000000
# date                0   0.000000
# T2M_MIN             0   0.000000
# T2M_MAX             0   0.000000
# T2MWET              0   0.000000
# T2MDEW              0   0.000000
# T2M                 0   0.000000
# QV2M                0   0.000000
# PS                  0   0.000000
# PRECTOT             0   0.000000
# T2M_RANGE           0   0.000000

# %%
# TEST_SET Null Value exploration
missing_test = pd.concat([test_set.isnull().sum(), 100 * test_set.isnull().mean()], axis=1)
missing_test.columns=['count', '%']
missing_test.sort_values(by='count', ascending=False)
# Out:
#                count          %
# score        1945608  85.636115
# TS                 0   0.000000
# WS50M_RANGE        0   0.000000
# WS50M_MIN          0   0.000000
# WS50M_MAX          0   0.000000
# WS50M              0   0.000000
# WS10M_RANGE        0   0.000000
# WS10M_MIN          0   0.000000
# WS10M_MAX          0   0.000000
# WS10M              0   0.000000
# fips               0   0.000000
# date               0   0.000000
# T2M_MIN            0   0.000000
# T2M_MAX            0   0.000000
# T2MWET             0   0.000000
# T2MDEW             0   0.000000
# T2M                0   0.000000
# QV2M               0   0.000000
# PS                 0   0.000000
# PRECTOT            0   0.000000
# T2M_RANGE          0   0.000000

# %% [markdown]
# <b> Null Value Synopsis:</b> This clean dataset comes from Kaggle.  The weekly drought assessment and the daily meteorological values have different frequencies, which is why there are score field NaN values.
# Because of the way the data is integrated, six of the seven days will be null.  6/7 is 85.71%.

# %% [markdown]
# <h3> Numeric Features of the Datasets </h3>

# %%
# Numerical features of the soil dataset.
soil_set.describe().T
# Out:
#                 count          mean           std          min           25%  \
# fips           3109.0  30678.538437  14986.018730  1001.000000  19045.000000
# lat            3109.0     38.280052      4.838634    25.601043     34.686818
# lon            3109.0    -91.659790     11.485291  -124.211407    -98.046842
# elevation      3109.0    427.624638    500.158880    -1.000000    132.000000
# slope1         3109.0      0.054973      0.089873     0.000000      0.008300
# slope2         3109.0      0.297750      0.215950     0.000000      0.105100
# slope3         3109.0      0.319991      0.167727     0.000000      0.185800
# slope4         3109.0      0.155878      0.128400     0.000000      0.040800
# slope5         3109.0      0.053409      0.073107     0.000000      0.000500
# slope6         3109.0      0.065323      0.125526     0.000000      0.000000
# slope7         3109.0      0.022223      0.064127     0.000000      0.000000
# slope8         3109.0      0.009267      0.044933     0.000000      0.000000
# aspectN        3109.0      0.143749      0.078237     0.000000      0.086200
# aspectE        3109.0      0.168888      0.084105     0.000000      0.109200
# aspectS        3109.0      0.148392      0.082111     0.000000      0.086300
# aspectW        3109.0      0.165061      0.087843     0.000000      0.101500
# aspectUnknown  3109.0      0.352723      0.272182     0.000000      0.115600
# WAT_LAND       3109.0      2.850511     13.159247     0.000000      0.000000
# NVG_LAND       3109.0      1.801451      7.971805     0.000000      0.000000
# URB_LAND       3109.0      2.670026      9.770693     0.000000      0.104800
# GRS_LAND       3109.0     19.812154     25.447435     0.000000      4.360057
# FOR_LAND       3109.0     39.296586     34.365530     0.000000      4.552230
# CULTRF_LAND    3109.0     28.494804     31.839502     0.000000      0.143526
# CULTIR_LAND    3109.0      3.504682     10.290893     0.000000      0.045909
# CULT_LAND      3109.0     31.999486     33.099657     0.000000      1.602227
# SQ1            3109.0      1.830492      1.192219     0.000000      1.000000
# SQ2            3109.0      1.553554      1.021382     0.000000      1.000000
# SQ3            3109.0      1.282084      1.002508     0.000000      1.000000
# SQ4            3109.0      1.357350      1.030110     0.000000      1.000000
# SQ5            3109.0      1.146993      0.922308     0.000000      1.000000
# SQ6            3109.0      1.135092      0.914502     0.000000      1.000000
# SQ7            3109.0      1.284979      1.017465     0.000000      1.000000
#
#                         50%           75%           max
# fips           29213.000000  46009.000000  56045.000000
# lat               38.328061     41.703590     48.842653
# lon              -90.181170    -83.373303    -67.609354
# elevation        272.000000    483.000000   3561.000000
# slope1             0.028300      0.068500      0.974000
# slope2             0.271000      0.477500      0.759900
# slope3             0.347100      0.459300      0.696900
# slope4             0.127500      0.255200      0.571700
# slope5             0.012200      0.090300      0.330000
# slope6             0.000700      0.054100      0.606800
# slope7             0.000000      0.001200      0.476500
# slope8             0.000000      0.000000      0.628800
# aspectN            0.144200      0.195600      0.478400
# aspectE            0.174000      0.227600      0.738500
# aspectS            0.148300      0.206600      0.511200
# aspectW            0.165500      0.223100      0.657800
# aspectUnknown      0.305900      0.555200      1.000000
# WAT_LAND           0.000000      0.000000    100.000000
# NVG_LAND           0.000000      0.000000     99.982918
# URB_LAND           0.488500      1.115100     99.998764
# GRS_LAND           8.839095     23.720787     99.998596
# FOR_LAND          30.573359     74.532990     91.044609
# CULTRF_LAND       14.043937     51.737080     97.029572
# CULTIR_LAND        0.276606      1.370315     99.956841
# CULT_LAND         18.811279     60.637421     99.956841
# SQ1                1.000000      3.000000      7.000000
# SQ2                1.000000      2.000000      7.000000
# SQ3                1.000000      1.000000      7.000000
# SQ4                1.000000      1.000000      7.000000
# SQ5                1.000000      1.000000      7.000000
# SQ6                1.000000      1.000000      7.000000
# SQ7                1.000000      1.000000      7.000000

# %%
# Numerical features of the training dataset.
train_set.describe().T
# Out:
#                   count                           mean                  min  \
# fips         19300680.0                    30670.37677               1001.0
# date           19300680  2008-07-01 11:59:59.999999744  2000-01-01 00:00:00
# PRECTOT      19300680.0                       2.644145                  0.0
# PS           19300680.0                      96.655785                66.12
# QV2M         19300680.0                       7.816178                 0.12
# T2M          19300680.0                      12.801455               -37.34
# T2MDEW       19300680.0                       6.951072                -37.7
# T2MWET       19300680.0                       6.986916               -37.46
# T2M_MAX      19300680.0                      18.681408                -32.2
# T2M_MIN      19300680.0                       7.411665               -45.96
# T2M_RANGE    19300680.0                      11.269745                 0.03
# TS           19300680.0                      12.888998               -38.23
# WS10M        19300680.0                       3.564013                 0.25
# WS10M_MAX    19300680.0                       5.195993                 0.54
# WS10M_MIN    19300680.0                       1.928879                  0.0
# WS10M_RANGE  19300680.0                       3.267113                 0.16
# WS50M        19300680.0                       5.525151                  0.4
# WS50M_MAX    19300680.0                       7.811798                  0.7
# WS50M_MIN    19300680.0                       3.130077                  0.0
# WS50M_RANGE  19300680.0                       4.681721                 0.32
# score         2756796.0                        0.82453                  0.0
#
#                              25%                  50%                  75%  \
# fips                     19044.5              29212.0              46007.5
# date         2004-04-01 00:00:00  2008-07-01 12:00:00  2012-10-01 00:00:00
# PRECTOT                      0.0                 0.18                 2.16
# PS                         95.84                 98.3                99.96
# QV2M                        3.78                 6.84                11.35
# T2M                         4.45                14.02                21.88
# T2MDEW                     -0.96                 7.57                15.52
# T2MWET                     -0.92                 7.58                15.52
# T2M_MAX                    10.27                 20.4                27.87
# T2M_MIN                     -0.7                 8.03                16.14
# T2M_RANGE                   8.42                11.24                14.08
# TS                          4.34                14.04                22.07
# WS10M                       2.14                 3.14                  4.6
# WS10M_MAX                   3.11                 4.67                 6.75
# WS10M_MIN                   0.96                 1.66                 2.58
# WS10M_RANGE                 1.81                  2.8                 4.25
# WS50M                       3.79                 5.12                 6.88
# WS50M_MAX                   5.68                 7.31                 9.46
# WS50M_MIN                   1.45                 2.77                 4.41
# WS50M_RANGE                 3.13                 4.25                 5.77
# score                        0.0                  0.0               1.1896
#
#                              max           std
# fips                     56043.0  14979.107776
# date         2016-12-31 00:00:00           NaN
# PRECTOT                   234.59      6.226305
# PS                        104.32      5.447994
# QV2M                       22.92      4.694305
# T2M                        41.39      10.92674
# T2MDEW                     27.55     10.145507
# T2MWET                     27.55      10.09116
# T2M_MAX                    49.91     11.544871
# T2M_MIN                     33.8     10.576797
# T2M_RANGE                  34.61      4.005165
# TS                         43.85     11.149612
# WS10M                      23.69      1.862297
# WS10M_MAX                  36.28      2.627969
# WS10M_MIN                   17.2      1.351713
# WS10M_RANGE                28.25      1.947028
# WS50M                      28.35      2.321549
# WS50M_MAX                  42.73       2.86121
# WS50M_MIN                  20.87      2.122751
# WS50M_RANGE                32.43      2.171263
# score                        5.0      1.223727

# %%
# Numerical features of the validation dataset.
validation_set.describe().T
# Out:
#                  count                 mean                  min  \
# fips         2268840.0          30670.37677               1001.0
# date           2268840  2017-12-31 12:00:00  2017-01-01 00:00:00
# PRECTOT      2268840.0             2.945218                  0.0
# PS           2268840.0            96.682894                66.86
# QV2M         2268840.0             8.209934                 0.16
# T2M          2268840.0            13.136803               -33.29
# T2MDEW       2268840.0             7.626656               -37.01
# T2MWET       2268840.0             7.631953               -33.58
# T2M_MAX      2268840.0            18.847392               -28.59
# T2M_MIN      2268840.0             7.903998               -38.15
# T2M_RANGE    2268840.0            10.943396                 0.02
# TS           2268840.0            13.217935               -35.48
# WS10M        2268840.0             3.533742                 0.37
# WS10M_MAX    2268840.0             5.165298                  0.6
# WS10M_MIN    2268840.0             1.904352                  0.0
# WS10M_RANGE  2268840.0             3.260947                 0.22
# WS50M        2268840.0             5.486969                 0.46
# WS50M_MAX    2268840.0             7.762958                 0.87
# WS50M_MIN    2268840.0             3.104674                  0.0
# WS50M_RANGE  2268840.0             4.658297                  0.3
# score         323232.0             0.538601                  0.0
#
#                              25%                  50%                  75%  \
# fips                     19044.5              29212.0              46007.5
# date         2017-07-02 00:00:00  2017-12-31 12:00:00  2018-07-02 00:00:00
# PRECTOT                      0.0                 0.19                  2.5
# PS                         95.88                98.32                99.98
# QV2M                        3.92                 7.26                12.18
# T2M                         4.67                14.58                22.51
# T2MDEW                     -0.44                 8.51                16.71
# T2MWET                     -0.48                 8.42                16.65
# T2M_MAX                    10.35                20.81                28.24
# T2M_MIN                    -0.44                 8.67                17.01
# T2M_RANGE                   8.14                 10.9                13.64
# TS                          4.54                14.61                22.69
# WS10M                       2.12                 3.14                 4.56
# WS10M_MAX                   3.11                 4.67                 6.71
# WS10M_MIN                   0.94                 1.64                 2.56
# WS10M_RANGE                 1.81                 2.81                 4.25
# WS50M                       3.77                 5.12                 6.83
# WS50M_MAX                   5.64                  7.3                 9.42
# WS50M_MIN                   1.42                 2.76                 4.39
# WS50M_RANGE                 3.11                 4.22                 5.76
# score                        0.0                  0.0                  1.0
#
#                              max           std
# fips                     56043.0  14979.110689
# date         2018-12-31 00:00:00           NaN
# PRECTOT                   243.32      6.883588
# PS                        104.06      5.443892
# QV2M                       21.98      4.905189
# T2M                        40.62     10.935752
# T2MDEW                     26.84     10.497402
# T2MWET                     26.84     10.356828
# T2M_MAX                    50.03      11.51619
# T2M_MIN                    33.04     10.647081
# T2M_RANGE                  33.19      3.951253
# TS                         43.25     11.134324
# WS10M                      24.94       1.84501
# WS10M_MAX                  31.76      2.607319
# WS10M_MIN                  16.29      1.342821
# WS10M_RANGE                23.19      1.927159
# WS50M                      29.52      2.310433
# WS50M_MAX                  37.38      2.851491
# WS50M_MIN                  20.85      2.115034
# WS50M_RANGE                 28.9      2.155684
# score                        5.0      0.916711

# %%
# Numerical features of the test dataset.
test_set.describe().T
# Out:
#                  count                           mean                  min  \
# fips         2271948.0                    30670.37677               1001.0
# date           2271948  2019-12-31 23:59:59.999999232  2019-01-01 00:00:00
# PRECTOT      2271948.0                       2.938845                  0.0
# PS           2271948.0                      96.661749                66.75
# QV2M         2271948.0                       8.223259                  0.1
# T2M          2271948.0                      12.945749               -38.57
# T2MDEW       2271948.0                       7.782536               -41.54
# T2MWET       2271948.0                       7.793077               -38.59
# T2M_MAX      2271948.0                      18.612241               -31.33
# T2M_MIN      2271948.0                       7.737146               -45.46
# T2M_RANGE    2271948.0                      10.875095                 0.12
# TS           2271948.0                      12.981557               -41.23
# WS10M        2271948.0                       3.528208                 0.26
# WS10M_MAX    2271948.0                       5.177723                  0.6
# WS10M_MIN    2271948.0                       1.880345                  0.0
# WS10M_RANGE  2271948.0                       3.297381                 0.23
# WS50M        2271948.0                       5.486035                 0.52
# WS50M_MAX    2271948.0                       7.804205                 1.04
# WS50M_MIN    2271948.0                       3.060228                  0.0
# WS50M_RANGE  2271948.0                       4.743982                 0.45
# score         326340.0                       0.413486                  0.0
#
#                              25%                  50%                  75%  \
# fips                     19044.5              29212.0              46007.5
# date         2019-07-02 00:00:00  2020-01-01 00:00:00  2020-07-02 00:00:00
# PRECTOT                      0.0                 0.21                 2.54
# PS                         95.86                 98.3                99.96
# QV2M                        3.96                 7.06                12.22
# T2M                         4.53                13.89                22.23
# T2MDEW                     -0.16                 8.25                16.85
# T2MWET                     -0.11                 8.09                16.71
# T2M_MAX                    10.18                20.14                27.87
# T2M_MIN                     -0.5                 8.08                 16.8
# T2M_RANGE                   8.14                10.78                13.53
# TS                          4.41                13.88                22.36
# WS10M                       2.12                 3.14                 4.54
# WS10M_MAX                   3.11                 4.68                 6.71
# WS10M_MIN                   0.94                 1.62                 2.53
# WS10M_RANGE                 1.82                 2.82                  4.3
# WS50M                       3.79                  5.1                 6.82
# WS50M_MAX                   5.67                 7.31                 9.45
# WS50M_MIN                   1.41                 2.72                 4.32
# WS50M_RANGE                 3.16                  4.3                 5.86
# score                        0.0                  0.0             0.406525
#
#                              max           std
# fips                     56043.0  14979.110684
# date         2020-12-31 00:00:00           NaN
# PRECTOT                   249.34      6.719112
# PS                        103.88      5.443289
# QV2M                       22.52      4.925266
# T2M                        40.33     10.859401
# T2MDEW                     27.05     10.333155
# T2MWET                      27.0     10.104503
# T2M_MAX                     48.3     11.403874
# T2M_MIN                    32.32     10.632098
# T2M_RANGE                  29.65       3.85062
# TS                         43.47      11.06347
# WS10M                      17.48       1.83456
# WS10M_MAX                  24.97      2.618564
# WS10M_MIN                  16.51      1.310424
# WS10M_RANGE                22.07      1.971088
# WS50M                      20.58      2.291324
# WS50M_MAX                  29.93       2.86998
# WS50M_MIN                  19.22      2.071117
# WS50M_RANGE                26.34      2.202233
# score                        5.0      0.838403

# %% [markdown]
# ### Exploring the NaN values in the Drought Score ['score'] field:

# %%
# Exploring the NaN values in the score field of the training dataset.
train_set[['fips', 'date', 'score']].head(30)
# Out:
#     fips       date  score
# 0   1001 2000-01-01    NaN
# 1   1001 2000-01-02    NaN
# 2   1001 2000-01-03    NaN
# 3   1001 2000-01-04    1.0
# 4   1001 2000-01-05    NaN
# 5   1001 2000-01-06    NaN
# 6   1001 2000-01-07    NaN
# 7   1001 2000-01-08    NaN
# 8   1001 2000-01-09    NaN
# 9   1001 2000-01-10    NaN
# 10  1001 2000-01-11    2.0
# 11  1001 2000-01-12    NaN
# 12  1001 2000-01-13    NaN
# 13  1001 2000-01-14    NaN
# 14  1001 2000-01-15    NaN
# 15  1001 2000-01-16    NaN
# 16  1001 2000-01-17    NaN
# 17  1001 2000-01-18    2.0
# 18  1001 2000-01-19    NaN
# 19  1001 2000-01-20    NaN
# 20  1001 2000-01-21    NaN
# 21  1001 2000-01-22    NaN
# 22  1001 2000-01-23    NaN
# 23  1001 2000-01-24    NaN
# 24  1001 2000-01-25    2.0
# 25  1001 2000-01-26    NaN
# 26  1001 2000-01-27    NaN
# 27  1001 2000-01-28    NaN
# 28  1001 2000-01-29    NaN
# 29  1001 2000-01-30    NaN

# %%
# There are six categories for drought.  No drought is encoded as 'None'
train_set[train_set['score'] == 'None']
# Out:
# Empty DataFrame
# Columns: [fips, date, PRECTOT, PS, QV2M, T2M, T2MDEW, T2MWET, T2M_MAX, T2M_MIN, T2M_RANGE, TS, WS10M, WS10M_MAX, WS10M_MIN, WS10M_RANGE, WS50M, WS50M_MAX, WS50M_MIN, WS50M_RANGE, score]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Either the 'None' values in this dataset are encoded with the same NaN value as all the non-drought scored days, or there are no values in this dataset linked with 'None' on the Drought Scale.  <br>
# Tuesday, January 4, 2000, is the first non-null drought score, and it repeats every seven days after that.   Every Tuesday, I have to get data from the dataset and create statistics on the drought score based on that subset of data.  <br>
# Examine whether 0 rather than NaN can be used to denote No Data in datasets.

# %%
# Determining Day of the Week in the Training Dataset

train_set['date'] = pd.to_datetime(train_set['date'])
train_set['day_of_week'] = train_set['date'].dt.day_name()
train_set[['fips', 'date', 'day_of_week', 'score']].head(10)
# Out:
#    fips       date day_of_week  score
# 0  1001 2000-01-01    Saturday    NaN
# 1  1001 2000-01-02      Sunday    NaN
# 2  1001 2000-01-03      Monday    NaN
# 3  1001 2000-01-04     Tuesday    1.0
# 4  1001 2000-01-05   Wednesday    NaN
# 5  1001 2000-01-06    Thursday    NaN
# 6  1001 2000-01-07      Friday    NaN
# 7  1001 2000-01-08    Saturday    NaN
# 8  1001 2000-01-09      Sunday    NaN
# 9  1001 2000-01-10      Monday    NaN

# %%
train_set_Score = train_set[train_set['day_of_week'] == 'Tuesday']
train_set_Score.head()
# Out:
#     fips       date  PRECTOT      PS  QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 3   1001 2000-01-04    15.95  100.29  6.42  11.40    6.09    6.10    18.09
# 10  1001 2000-01-11     1.33  100.40  6.63  11.48    7.84    7.84    18.88
# 17  1001 2000-01-18     1.11  100.39  9.53  14.28   13.26   13.26    18.04
# 24  1001 2000-01-25     0.00  100.11  2.05  -0.78   -7.93   -7.72     5.65
# 31  1001 2000-02-01     0.00  101.00  3.36   2.06   -1.73   -1.70    11.02
#
#     T2M_MIN  ...  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  WS50M_MAX  \
# 3      2.16  ...   3.84       5.67       2.08         3.59   6.73       9.31
# 10     5.72  ...   1.76       2.48       1.05         1.43   3.55       6.38
# 17     8.98  ...   2.63       3.60       1.67         1.92   5.19       6.40
# 24    -5.46  ...   3.35       4.59       2.28         2.32   5.75       8.03
# 31    -4.21  ...   2.03       2.74       0.88         1.86   4.18       6.38
#
#     WS50M_MIN  WS50M_RANGE  score  day_of_week
# 3        3.74         5.58    1.0      Tuesday
# 10       1.71         4.67    2.0      Tuesday
# 17       3.84         2.55    2.0      Tuesday
# 24       3.96         4.07    2.0      Tuesday
# 31       1.27         5.11    1.0      Tuesday
#
# [5 rows x 22 columns]

# %%
# TRAIN_SET_SCORE Null Value exploration when there should be a value for Drought Score
missing_train_Score = pd.concat([train_set_Score.isnull().sum(), 100 * train_set_Score.isnull().mean()], axis=1)
missing_train_Score.columns=['count', '%']
missing_train_Score.sort_values(by='count', ascending=False)
# Out:
#              count    %
# fips             0  0.0
# date             0  0.0
# score            0  0.0
# WS50M_RANGE      0  0.0
# WS50M_MIN        0  0.0
# WS50M_MAX        0  0.0
# WS50M            0  0.0
# WS10M_RANGE      0  0.0
# WS10M_MIN        0  0.0
# WS10M_MAX        0  0.0
# WS10M            0  0.0
# TS               0  0.0
# T2M_RANGE        0  0.0
# T2M_MIN          0  0.0
# T2M_MAX          0  0.0
# T2MWET           0  0.0
# T2MDEW           0  0.0
# T2M              0  0.0
# QV2M             0  0.0
# PS               0  0.0
# PRECTOT          0  0.0
# day_of_week      0  0.0

# %% [markdown]
# There are no NaN or null values for score from the Tuesday subset.

# %%
# Numerical features of the training dataset with DROUGHT SCORE non-null.
train_set_Score.describe().T
# Out:
#                  count                           mean                  min  \
# fips         2756796.0                    30670.37677               1001.0
# date           2756796  2008-07-01 00:00:00.000000256  2000-01-04 00:00:00
# PRECTOT      2756796.0                       2.714566                  0.0
# PS           2756796.0                      96.647365                66.49
# QV2M         2756796.0                        7.87577                 0.14
# T2M          2756796.0                       12.89923               -35.44
# T2MDEW       2756796.0                        7.04935               -35.44
# T2MWET       2756796.0                       7.084938               -35.46
# T2M_MAX      2756796.0                       18.76711               -30.03
# T2M_MIN      2756796.0                       7.519916               -40.85
# T2M_RANGE    2756796.0                      11.247201                 0.16
# TS           2756796.0                      12.974928               -37.16
# WS10M        2756796.0                       3.564075                 0.29
# WS10M_MAX    2756796.0                       5.202917                 0.57
# WS10M_MIN    2756796.0                       1.920655                  0.0
# WS10M_RANGE  2756796.0                       3.282268                 0.26
# WS50M        2756796.0                       5.532799                 0.51
# WS50M_MAX    2756796.0                       7.828799                 0.85
# WS50M_MIN    2756796.0                       3.121578                  0.0
# WS50M_RANGE  2756796.0                       4.707223                 0.42
# score        2756796.0                        0.82453                  0.0
#
#                              25%                  50%                  75%  \
# fips                     19044.5              29212.0              46007.5
# date         2004-03-30 00:00:00  2008-07-01 00:00:00  2012-10-02 00:00:00
# PRECTOT                      0.0                 0.19                 2.26
# PS                         95.83                98.28                99.94
# QV2M                        3.81                 6.94                11.45
# T2M                         4.58                14.21                 22.0
# T2MDEW                     -0.88                 7.81                15.67
# T2MWET                     -0.84                 7.81                15.67
# T2M_MAX                    10.36                20.62                27.97
# T2M_MIN                    -0.57                 8.26                16.28
# T2M_RANGE                   8.37                 11.2                14.08
# TS                          4.46                14.23                22.18
# WS10M                       2.14                 3.16                 4.59
# WS10M_MAX                   3.13                  4.7                 6.76
# WS10M_MIN                   0.96                 1.66                 2.57
# WS10M_RANGE                 1.82                 2.82                 4.28
# WS50M                       3.82                 5.15                 6.88
# WS50M_MAX                    5.7                 7.35                 9.49
# WS50M_MIN                   1.45                 2.77                 4.39
# WS50M_RANGE                 3.14                 4.27                 5.81
# score                        0.0                  0.0               1.1896
#
#                              max           std
# fips                     56043.0  14979.110105
# date         2016-12-27 00:00:00           NaN
# PRECTOT                   168.69       6.24759
# PS                        103.76      5.444698
# QV2M                       22.12      4.721459
# T2M                        39.33     10.970402
# T2MDEW                     26.87      10.19765
# T2MWET                     26.87     10.143641
# T2M_MAX                    47.75     11.602952
# T2M_MIN                    32.28     10.618183
# T2M_RANGE                  30.17      4.038022
# TS                         42.48     11.190949
# WS10M                      19.75      1.847645
# WS10M_MAX                  24.74      2.609219
# WS10M_MIN                  14.62      1.342458
# WS10M_RANGE                18.72      1.943136
# WS50M                      22.47       2.29855
# WS50M_MAX                  28.33      2.836618
# WS50M_MIN                  17.78      2.109945
# WS50M_RANGE                23.37       2.18102
# score                        5.0      1.223727

# %% [markdown]
# The count for score is the same as for the entire training dataset.

# %%
#### How many unique counties are in the full training dataset?
ts_fips_unique = train_set['fips'].unique()
type(ts_fips_unique)
# Out:
# numpy.ndarray

# %%
train_set.fips.value_counts().head()
# Out:
# fips
# 1001     6210
# 39159    6210
# 39115    6210
# 39117    6210
# 39119    6210
# Name: count, dtype: int64

# %%
ts_fips_unique
# Out:
# array([ 1001,  1003,  1005, ..., 56039, 56041, 56043])

# %%
ts_fips_count_unique = 0
for i in ts_fips_unique:
    ts_fips_count_unique += 1
ts_fips_count_unique
# Out:
# 3108

# %% [markdown]
# <b> Training Set is county data from 2000-2009.  There are 3108 unique counties in the dataset. </b>

# %%
# Determing character and composition of the Drought Score field
train_set_Score[['fips', 'date', 'score']].head(30)
# Out:
#      fips       date   score
# 3    1001 2000-01-04  1.0000
# 10   1001 2000-01-11  2.0000
# 17   1001 2000-01-18  2.0000
# 24   1001 2000-01-25  2.0000
# 31   1001 2000-02-01  1.0000
# 38   1001 2000-02-08  1.0000
# 45   1001 2000-02-15  1.0000
# 52   1001 2000-02-22  1.0000
# 59   1001 2000-02-29  1.0000
# 66   1001 2000-03-07  1.0000
# 73   1001 2000-03-14  1.4905
# 80   1001 2000-03-21  1.5019
# 87   1001 2000-03-28  1.2818
# 94   1001 2000-04-04  1.0000
# 101  1001 2000-04-11  0.9290
# 108  1001 2000-04-18  1.0000
# 115  1001 2000-04-25  1.0000
# 122  1001 2000-05-02  1.0481
# 129  1001 2000-05-09  1.9995
# 136  1001 2000-05-16  2.0391
# 143  1001 2000-05-23  2.0390
# 150  1001 2000-05-30  2.0391
# 157  1001 2000-06-06  2.0391
# 164  1001 2000-06-13  3.0946
# 171  1001 2000-06-20  3.0946
# 178  1001 2000-06-27  3.0000
# 185  1001 2000-07-04  3.0000
# 192  1001 2000-07-11  3.9795
# 199  1001 2000-07-18  4.7134
# 206  1001 2000-07-25  5.0000

# %% [markdown]
# ### Histogram of Drought Severity within the Training Dataset.

# %%
#A histogram detailing the distribution of drought severity within the training dataset.
train_set_Score['score'].hist(bins=5)
# Out:
# <Axes: >

# %% [markdown]
# <b> The dataset does not contain data from times when there is no drought or a drought score of 'None' or 'No Data'.  The dataset only contains information for when there was some level of drought occuring. </b>

# %% [markdown]
# ## Summary of Initial Data Wrangling
#
# * The meteorological data is over 3GBs and are daily measurements spanning 2 decades.  This may exceed my current processing power.  I am installing a Linux/Windows dual-boot system for my desktop to help alleviate processing issues.  Alternatively, the daily meteorological measurements may be condensed into a weekly statistic to correspond with the weekly drought score. <br>
# <br>
# * The weekly drought score was originally an integer or category: None, D0, D1, D2, D3, D4, & NoData. See the Data Dictionary for descriptions of the categorical degrees of drought.<br>
#
# | Category | Drought Score |
# | -: | :- |
# | None | 0 |
# | D0 | 1 |
# | D1 | 2 |
# | D2 | 3 |
# | D3 | 4 |
# | D4 | 5 |
#
#
# * A linear regression should be explored with the floating point drought score.  But the next step beyond that is to convert the floating point numbers that are in the score column back to categorical values to correspond with None, D0, D1, D2, D3, & D4.<br>
# <br>
# * The discussion on how the continuous score values were calculated from categorical values is here:<br>
# https://www.kaggle.com/datasets/cdminix/us-drought-meteorological-data/discussion/299527 <br>
# The counties were given a percentage of how much of each county was in which drought state and then those floating point numbers were interpolated based on the location of the meteorological data.  The GitHub repo showing the preprocessing is here:<br> https://github.com/MiniXC/droughted_scripts <br>
# <br>
# * The date ranges for the Training, Validation, and Test Sets do not correspond with the metadata, but there is still no overlap and there is not any concern about data leakage.  The date ranges are: <br>
#
# | Data Set | Date Range |
# | -: | :- |
# | Training Set | 2000 - 2016 |
# | Validation Set | 2017 - 2018 |
# | Test  Set | 2019 - 2020 |
#
# <br>
# * There are no issues in the dataset associated with missing data.  The dataset does not contain null values or instances of NoData. <br>
